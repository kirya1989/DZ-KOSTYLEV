# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from gapminder import gapminder

# %%
data = gapminder[gapminder.year == 1972].copy()

data['country'] = pd.Categorical(data['country'])

# %%
plt.scatter(x=data['lifeExp'], y=data['gdpPercap'], s=data['pop'] / 1000, c=data['country'].cat.codes, alpha=0.5)
